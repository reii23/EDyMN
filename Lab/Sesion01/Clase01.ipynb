# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Ingreso de funciones
#
# Para ingresar funciones en Python se puede utilizar el comando `def` que permite definir un bloque de código ejecutable.

# %% [markdown]
# Para definir y utilizar la función $f(x)=x^2+x-1$ se puede utilizar la siguiente linea de código

# %%
def f(x):
    return x**2 + x - 1

# %% [markdown]
# De esta manera se puede definir cualquier función matemática que se necesite evaluar.

# %% [markdown]
# # Gráficos en Python
#
# En ocasiones, debido a que ciertas ecuaciones diferenciales no poseen soluciones explícitas, es necesario realizar un análisis cualitativo de las soluciones, es decir, interpretar de manera gráfica algunos resultados. Por medio del estudio de la gráfica de la familia de soluciones podemos entender el comportamiento de las soluciones y poder usarlas para describir fenómenos, sin necesidad de utilizar alguna técnica de resolución para determinar la solución general de la EDO.
#
# Para graficar funciones de una variable, utilizamos la librería matplotlib.pyplot cuya documentación completa se puede encontrar en el enlace
#
# https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.html

# %% [markdown]
# Para realizar un gráfico en 2D utilizamos la función plt.plot(), cuyos argumentos principales corresponden una lista o arreglo de valores asociados al dominio de la función y la función a graficar.

# %% [markdown]
# Podemos gráficar la función antes definida utilizando la siguiente linea de código

# %%
import matplotlib.pyplot as plt
import numpy as np

def f(x):
    return x**2 + x - 1

x = np.linspace(-10, 10, 400) 
y = f(x)

plt.plot(x, y)
plt.xlabel('x')
plt.ylabel('f(x)')
plt.title('Gráfico de la función f(x) = x^2 + x - 1')
plt.grid(True)
plt.show()

# %% [markdown]
# Notamos que mientras la partición en x sea más fina, la curva es cada vez mas suave.
#
# Es posible graficar más de una función en un mismo gráfico:

# %%
import matplotlib.pyplot as plt
import numpy as np

def f(x):
    return x**2 + x - 1

def g(x):
    return x**3 - x

x = np.linspace(-10, 10, 1000) 

y_f = f(x)
y_g = g(x)

plt.plot(x, y_f, label='f(x) = x^2 + x - 1')
plt.plot(x, y_g, label='g(x) = x^3 - x')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Gráfico de f(x) y g(x)')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# La presentación de las curvas en cuanto a color, grosor, forma, etc son presentados siempre por defecto de la misma manera.
# Si se desea personalizar el gráfico es posible utlizar algunas de las siguientes funciones:
# * `linewidth`: Personaliza el grosor de la línea.
# * `linestyle`: Personaliza el estilo de línea. El formato debe ser ingresado en cremillas, algunos formatos soportados son
#         * '-' o 'solid': formato por defecto.
#         * '--' o 'dashed': formato por líneas.
#         * '-.' o 'dashdot': formato línea punto.
#         * ' ' o 'none': formato ¿absurdo?
#         * ':' o 'dotted': formato de puntos.
# * `color`: Personaliza el color de la curva en formato (R,G,B) o bien con nombre directo. Una buena página para seleccionar colores es https://matplotlib.org/stable/gallery/color/named_colors.html

# %%
import matplotlib.pyplot as plt
import numpy as np

def f(x):
    return x**2 + x - 1

def g(x):
    return x**3 - x

x = np.linspace(-10, 10, 1000)

y_f = f(x)
y_g = g(x)

plt.plot(x, y_f, label='f(x) = x^2 + x - 1', color='blue', linewidth=2, linestyle='-')
plt.plot(x, y_g, label='g(x) = x^3 - x', color='red', linewidth=2, linestyle='--')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Gráfico Personalizado de f(x) y g(x)')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# En adición, es posible utilizar las siguientes funciones:
# * `plt.xlabel(' ')`: Añade etiqueta al eje de variables independientes.
# * `plt.ylabel(' ')`: Añade etiqueta al eje de varibles dependientes.
# * `plt.grid()`: Agrega una grilla (o red) al gráfico.
# * `plt.title('<titulo>')`: Agrega un título al gráfico.
# * `plt.xlim([<lim inferior>, <lim superior>])`: Margen de visualización variable independiente
# * `plt.ylim([<lim inferior>, <lim superior>])`: Margen de visualización variable dependiente
# * `plt.legend()`: Agrega una leyenda al gráfico. Para ello es necesario agregar con anterioridad una etiqueta a cada función, vía `label`, por ejemplo `plt.plot(x,y, label='función')`

# %% [markdown]
# # Un par de funciones adicionales con arreglos
# * `matplotlib.pyplot.quiver([X,Y],U,V)`: X, Y define las coordenadas del inicio de un vector y U, V define la dirección de la flecha

# %%
X,Y=[2,3]
U,V=[1,5]

plt.quiver(X,Y,U,V)
plt.grid()

# %%
X,Y=[[2,2],[2,3]]
U,V=[[1,2],[1,1]]

plt.grid()

plt.quiver(X,Y,U,V)

# %% [markdown]
# `meshgrid` devuelve una lista de matrices de coordenadas a partir de vectores de coordenadas.

# %%
X = np.linspace(-1, 1, 3)
Y = np.linspace(-1, 1, 3)

X,Y = np.meshgrid(X,Y)
X,Y
# Out:
# (array([[-1.,  0.,  1.],
#         [-1.,  0.,  1.],
#         [-1.,  0.,  1.]]),
#  array([[-1., -1., -1.],
#         [ 0.,  0.,  0.],
#         [ 1.,  1.,  1.]]))

# %% [markdown]
# ## Campo de direcciones
#
# Corresponde a un bosquejo con pequeños segmentos de recta trazados en un sistema de coordenadas cartesianas $xy$ (o simplemente plano $xy$), donde se muestra el comportamiento de la pendiente de la curva solución a la EDO $y'=f(x,y)$.
#
# Para generar dicho bosquejo en Python, podemos utilizar las funciones anteriormente mencionadas, en este sentido, en vez de graficar "pequeños segmentos" en la práctica graficamos vectores unitarios en las direcciones correspondientes.
#
#
# ## Ejemplo 1
#
# Para iniciar nuestro estudio consideremos la EDO vista en clase teórica
# $$ y'= 2y $$
# y generemos el campo de direcciones asociado a la ecuación.

# %%
X,Y=np.meshgrid(np.linspace(-4,4,9), np.linspace(-4,4,9))

U = 1.0
V = 2*Y

N = np.sqrt(U ** 2 + V ** 2)#Normalizamos los vectores
U = U / N
V = V / N

plt.quiver(X, Y, U, V) #graficamos los vectores con origen en (x,y) y término (u,v)
plt.xlim([-5, 5]) #limites en eje x
plt.ylim([-5, 5]) #limites en eje y

plt.xlabel('x') #etiqueta eje x
plt.ylabel('y') #etiqueta eje y
plt.grid()# para establecer red en la región

# %% [markdown]
# ## Ejemplo 2
# Considere la Ecuación Diferencial Ordinaria
# $$(x - y)dx - dy = 0$$
# * a) Grafique el campo de direcciones asociado en la región $[-5,5] \times [-5,5]$.
# * b) Grafique sobre el campo anterior la función $h(x)=e^{-x}+x-1$ y en base al gráfico justifique si $h$ es una solución particular de la EDO.
# * c) Realice el mismo estudio, esta vez con la función $s(x)=2e^{-x}-x+1$.

# %%
X,Y=np.meshgrid(np.linspace(-5,5,12), np.linspace(-5,5,12))

U = 1.0
V = X-Y

N = np.sqrt(U ** 2 + V ** 2)
U = U / N
V = V / N

plt.quiver(X, Y, U, V) 
plt.xlim([-5, 5]) 
plt.ylim([-5, 5]) 

plt.xlabel('x') 
plt.ylabel('y') 
plt.grid()

x=np.linspace(-5,5, 200)
def h(x): return np.exp(-x)+x-1
h=h(x)
plt.plot(x,h, label='h(x)')

def s(x): return 2*np.exp(-x)-x+1
s = s(x)
plt.plot(x, s, label='s(x)')
plt.legend()

# %% [markdown]
# ## EDO autónoma
#
# Una ecuación de la forma $y'=f(y)$, es decir, una ecuación diferencial de primer orden en donde $f$ depende solo de la variable dependiente se denomina ecuación autónoma.
#
# ## Ejemplo 3
#
# a) Identificar cuál de las siguientes EDO son autónomas.
#   *  $y'=3x-y^2$
#   *  $y'= (y-3)\ln(y^2+1)$
#   *  $ (y-1)(3-y)dx-dy=0 $
#
# b) Graficar los campos de direcciones asociados SOLO a las EDOs autónomas del item anterior.

# %%
X,Y=np.meshgrid(np.linspace(-7,7,15), np.linspace(-7,7,15))

U = 1.0
V = (Y-3)*np.log(Y**2+1)

N = np.sqrt(U ** 2 + V ** 2)#Normalizamos los vectores
U = U / N
V = V / N

plt.quiver(X, Y, U, V) #graficamos los vectores con origen en (x,y) y término (u,v)
plt.xlim([-8, 8]) #limites en eje x
plt.ylim([-8, 8]) #limites en eje y

plt.xlabel('x') #etiqueta eje x
plt.ylabel('y') #etiqueta eje y
plt.grid()# para establecer red en la región

# %%
X,Y=np.meshgrid(np.linspace(-5,9,15), np.linspace(-5,9,15))

U = 1.0
V = (Y-1)*(3-Y)

N = np.sqrt(U ** 2 + V ** 2)#Normalizamos los vectores
U = U / N
V = V / N

plt.quiver(X, Y, U, V) #graficamos los vectores con origen en (x,y) y término (u,v)
plt.xlim([-6, 10]) #limites en eje x
plt.ylim([-6, 10]) #limites en eje y

plt.xlabel('x') #etiqueta eje x
plt.ylabel('y') #etiqueta eje y
plt.grid()# para establecer red en la región

# %% [markdown]
# ## Puntos de equilibrio
#
# Dada una EDO autónoma $y'=f(y)$, si $f(y_0) = 0$ diremos que la recta $y = y_0$ es una solución de equilibrio de la EDO autónoma, y al valor $y_0$ lo denominamos punto de equilibrio.
#
# ### Clasificación de puntos de equilibrio
#
# * Un punto de equilibrio $y_0$ se dirá sumidero o atractor si cualquier solución suficientemente cerca a $y = y_0$ tiende asintóticamente a $y_0$ a medida de que $x$ aumenta.
#
# * Un punto de equilibrio $y_0$ se dirá fuente o repulsor si cualquier solución suficientemente cerca a $y = y_0$ tiende asintóticamente a $y_0$ a medida de que $x$ decrece.
#
# * Un punto de equilibrio $y_0$ se dirá nodo si este no es fuente ni sumidero.

# %% [markdown]
# ### Ejemplo 4:  $y'=2-y$

# %%
X,Y=np.meshgrid(np.linspace(-5,9,15), np.linspace(-5,9,15))

U = 1.0
V = 2-Y

N = np.sqrt(U ** 2 + V ** 2)#Normalizamos los vectores
U = U / N
V = V / N

plt.quiver(X, Y, U, V) #graficamos los vectores con origen en (x,y) y término (u,v)
plt.xlim([-6, 10]) #limites en eje x
plt.ylim([-6, 10]) #limites en eje y

plt.xlabel('x') #etiqueta eje x
plt.ylabel('y') #etiqueta eje y
plt.grid()# para establecer red en la región

# %% [markdown]
# El punto de equilibrio $y_0=2$ es un atractor

# %% [markdown]
# ### Ejemplo 5: $y'=y-2$

# %%
X,Y=np.meshgrid(np.linspace(-5,9,15), np.linspace(-5,9,15))

U = 1.0
V = Y-2

N = np.sqrt(U ** 2 + V ** 2)#Normalizamos los vectores
U = U / N
V = V / N

plt.quiver(X, Y, U, V) #graficamos los vectores con origen en (x,y) y término (u,v)
plt.xlim([-6, 10]) #limites en eje x
plt.ylim([-6, 10]) #limites en eje y

plt.xlabel('x') #etiqueta eje x
plt.ylabel('y') #etiqueta eje y
plt.grid()# para establecer red en la región

# %% [markdown]
# El punto de equilibrio $y_0=2$ es un repulsor

# %% [markdown]
# ### Ejemplo 6: $y'=(y-1)^2$

# %%
X,Y=np.meshgrid(np.linspace(-5,8,14), np.linspace(-5,8,14))

U = 1.0
V = (Y-1)**2

N = np.sqrt(U ** 2 + V ** 2)#Normalizamos los vectores
U = U / N
V = V / N

plt.quiver(X, Y, U, V) #graficamos los vectores con origen en (x,y) y término (u,v)
plt.xlim([-6, 9]) #limites en eje x
plt.ylim([-6, 9]) #limites en eje y

plt.xlabel('x') #etiqueta eje x
plt.ylabel('y') #etiqueta eje y
plt.grid()# para establecer red en la región

# %% [markdown]
# El punto de equilibrio $y_0=1$ es un nodo

# %% [markdown]
# ## Ejercicios
#
# * a) Considere la EDO
# $$ (y^2+3y-4)\sqrt{y} dx - dy = 0 $$
# verifique que es una EDO autónoma.
#
# * b) Clasifique todos sus puntos de equilibrio.
# * c) Grafique el campo de direcciones asociado a la EDO autónoma.
# * d) En base al retrato de fase, determine $\displaystyle\lim_{x\to \infty} y$ para $-4<y<0$.
# * e) Repita el proceso de d) esta vez para  $0<y<1$.

# %%
from sympy import symbols, Eq, solve
import numpy as np

def campo_dir(ax, slope_func, y_rng, arrows=20):
    y_vals = np.linspace(y_rng[0], y_rng[1], arrows)
    for y in y_vals:
        slope = slope_func(y)
        dx = 1 / np.sqrt(1 + slope**2)
        dy = slope * dx
        ax.quiver(0, y, dx, dy, angles='xy', scale_units='xy', scale=1, color='gray', alpha=0.5)

def slope(y):
    return (y**2 + 3*y - 4) * np.sqrt(y) if y >= 0 else 0

# Puntos de equilibrio
y = symbols('y')
eq = Eq(y**2 + 3*y - 4, 0)
eq_pts = solve(eq, y)
eq_pts_real = [pt.evalf() for pt in eq_pts if pt.is_real]

fig, ax = plt.subplots()
campo_dir(ax, slope, [-5, 2])

for pt in eq_pts_real:
    ax.plot(0, pt, 'ro')

ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_title('Campo de Direcciones')
ax.grid(True)
plt.xlim([-2, 2])
plt.ylim([-5, 2])
plt.show()
